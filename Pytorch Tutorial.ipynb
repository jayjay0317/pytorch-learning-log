# %% [markdown]
# # PyTorch Full Tutorial Course

# %% [markdown]
# **Video URL:** https://www.youtube.com/watch?v=k60oT_8lyFw

# %% [markdown]
# ## Overview
# This notebook covers the fundamental concepts of PyTorch, including Tensor operations, Autograd, and neural network construction.
